# %%
import numpy as np
import sympy as sp
import sympy.plotting as spl

# %% [markdown]
# # 1

# %%
x, y = sp.symbols('x y')
f = 9 - x - y
f
# Out:
# -x - y + 9

# %% [markdown]
# Første oktant er [+ + +]

# %%
print(sp.solve(sp.Eq(0, f), x))
print(sp.solve(sp.Eq(0, f), y))
# Out:
# [9 - y]
# [9 - x]

# %%
spl.plot3d(f, (x, 0, 9), (y, 0, 9))

# %%
grad=np.array([f.diff(x),f.diff(y)], dtype=float)
grad
# Out:
# array([-1., -1.])

# %%
absgrad = sp.nsimplify(np.sqrt(np.sum(grad**2)))
absgrad
# Out:
# sqrt(2)

# %% [markdown]
# # NB! Read up on me!

# %%
a = [x, 0, f]
b = [0, y, f]
da = [1, 0, f.diff(x)]
db = [0, 1, f.diff(y)]
cross = np.cross(da, db)
print(da)
print(db)
print(cross)
mag = np.sqrt(np.sum(np.array(cross,dtype=float)**2))
print(mag)
print(sp.nsimplify(mag))
# Out:
# [1, 0, -1]
# [0, 1, -1]
# [1 1 1]
# 1.7320508075688772
# sqrt(3)

# %%
F = sp.integrate(mag, (x, 0, 9-y), (y, 0, 9))

# %%
F
# Out:
# 70.1480577065395

# %%
sp.nsimplify(F)
# Out:
# 81*sqrt(3)/2

# %% [markdown]
# # 2

# %%
x, y, a = sp.symbols('x y a')

# %%
eqa = sp.Eq(y, -a*x+6)

# %%
sp.solve(eqa.subs({x: 9, y: 0}))
# Out:
# [2/3]

# %%
f = -6-(2/3)*x
spl.plot(f, (x, -10, 0))
spl.plot(-f, (x, 10, 0))

# %%
cross=np.cross([1, 0, y], [0, 1, x])
cross
# Out:
# array([-y, -x, 1], dtype=object)

# %%
s = 0
for n in cross:
    s += n**2

sp.sqrt(s)
# Out:
# sqrt(x**2 + y**2 + 1)
